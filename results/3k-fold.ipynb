# %% [markdown]
# ## Results for fold 1

# %%
import sys

# Utils
sys.path.append("../src/utils")
import results
# %matplotlib inline

# input
n_seeds = 30
csv_fname = "prediction_result_data/prediction_msh_tanzania_bal-1_acc_max.csv"

# load data from csv
data, header = results.load_csv(csv_fname)

# print 
print(header)
print(data)

# plot results
results.plot(data, n_seeds)
# Out:
# ['dataset_size', 'acc_1_max', 'acc_2_max(only drugs)']
# [[ 25.    82.11  88.81]
#  [ 50.    83.99  88.47]
#  [ 75.    84.18  88.47]
#  [100.    89.45  95.93]
#  [125.    91.34  97.63]
#  [150.    91.53  97.29]
#  [175.    93.22  96.61]
#  [200.    92.84  96.95]
#  [225.    92.47  96.95]
#  [250.    93.03  98.31]
#  [275.    93.6   96.95]
#  [300.    93.22  97.63]
#  [325.    93.03  97.29]
#  [350.    93.97  97.29]
#  [375.    93.79  97.63]
#  [400.    94.35  97.63]]

# %% [markdown]
# ## Results for fold 2

# %%
import sys

# Utils
sys.path.append("../src/utils")
import results
# %matplotlib inline

# input
n_seeds = 30
csv_fname = "prediction_result_data/prediction_msh_tanzania_bal-2_acc_max.csv"

# load data from csv
data, header = results.load_csv(csv_fname)

# print 
print(header)
print(data)

# plot results
results.plot(data, n_seeds)
# Out:
# ['dataset_size', 'acc_1_max', 'acc_2_max(only drugs)']
# [[ 25.    79.66  86.44]
#  [ 50.    86.44  91.53]
#  [ 75.    84.56  87.8 ]
#  [100.    89.08  95.25]
#  [125.    91.71  96.95]
#  [150.    91.53  96.27]
#  [175.    93.22  97.63]
#  [200.    93.97  97.63]
#  [225.    94.16  97.63]
#  [250.    93.6   96.95]
#  [275.    94.54  96.95]
#  [300.    94.35  97.29]
#  [325.    94.16  97.29]
#  [350.    94.35  97.97]
#  [375.    94.73  98.31]
#  [400.    94.54  99.32]]

# %% [markdown]
# ## Results for fold 3

# %%
import sys

# Utils
sys.path.append("../src/utils")
import results
# %matplotlib inline

# input
n_seeds = 30
csv_fname = "prediction_result_data/prediction_msh_tanzania_bal-3_acc_max.csv"

# load data from csv
data, header = results.load_csv(csv_fname)

# print 
print(header)
print(data)

# plot results
results.plot(data, n_seeds)
# Out:
# ['dataset_size', 'acc_1_max', 'acc_2_max(only drugs)']
# [[ 25.    83.05  87.46]
#  [ 50.    87.95  90.17]
#  [ 75.    86.25  91.19]
#  [100.    90.21  95.25]
#  [125.    90.4   96.27]
#  [150.    92.47  97.29]
#  [175.    91.9   96.61]
#  [200.    94.16  97.97]
#  [225.    92.84  97.29]
#  [250.    92.84  98.31]
#  [275.    93.03  97.97]
#  [300.    93.97  96.95]
#  [325.    94.73  98.31]
#  [350.    93.79  98.31]
#  [375.    93.97  98.31]
#  [400.    94.35  98.31]]
